# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Abbas\OneDrive\Pictures\Camera Roll\Desktop\mutual-fund-analytics\.venv\Scripts\python.exe

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

print("All libraries loaded")
# Out:
# All libraries loaded

# %%
from scipy.stats import linregress

print("Scipy Working")
# Out:
# Scipy Working
